# %%
from sklearn import datasets
import pandas as pd
iris = datasets.load_iris()
print(type(iris.data))
print(iris.feature_names)

iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)
iris_df.head()
# Out:
# <class 'numpy.ndarray'>
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

temperatures   = np.array([29, 28, 34, 31, 25, 29, 32, 31, 24, 33, 25, 31, 26, 30])
iced_tea_sales = np.array([77, 62, 93, 84, 59, 64, 80, 75, 58, 91, 51, 73, 65, 84])

lm = LinearRegression()
lm.fit(np.reshape(temperatures, (len(temperatures), 1)), np.reshape(iced_tea_sales, (len(iced_tea_sales), 1)))

# 印出係數
m = float(lm.coef_)
b = float(lm.intercept_)
print("y = ",m,"x + ",b)

# 新的氣溫
to_be_predicted = np.array([30])
predicted_sales = lm.predict(np.reshape(to_be_predicted, (len(to_be_predicted), 1)))

# 印出數據分布
#plt.plot(temperatures,iced_tea_sales,'ro')
plt.scatter(temperatures,iced_tea_sales,color='black')
plt.xlabel("temperatures")
plt.ylabel("iced_tea_sales")
plt.plot(temperatures, lm.predict(np.reshape(temperatures, (len(temperatures), 1))), color='blue', linewidth=3)
plt.plot(to_be_predicted, predicted_sales, color = 'red', marker = '^', markersize = 10)
plt.show
# Out:
# y =  3.7378854625550653 x +  -36.36123348017618
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import xlrd
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

filename = "awb.xlsx"
df = pd.read_excel(filename)
df.head(15)
D65_N = [df.iloc[:,0],df.iloc[:,1]]
D65_L = [df.iloc[:,2],df.iloc[:,3]]
COOLW = [df.iloc[:,4],df.iloc[:,5]]

plt.plot(COOLW[0],COOLW[1],'g*',D65_N[0],D65_N[1],'r^',D65_L[0],D65_L[1],'b.')
plt.xlabel("Bgain")
plt.ylabel("Rgain")
plt.savefig('AWB_Cluster_distribution.png') #it func can't use in behine plot.show() and save bmp.
plt.show()

Rgain = [ k for k in COOLW[0]] + [ k for k in D65_N[0]] + [ k for k in D65_L[0]]
Bgain = [ k for k in COOLW[1]] + [ k for k in D65_N[1]] + [ k for k in D65_L[1]]
Rgain = Rgain[:-3]
Bgain = Bgain[:-3]
plt.plot(Rgain,Bgain,'r*')
plt.xlabel("Bgain")
plt.ylabel("Rgain")


lm = LinearRegression()
lm.fit(np.reshape(Rgain, (len(Rgain), 1)), np.reshape(Bgain, (len(Bgain), 1)))


#plt.xlabel("temperatures")
#plt.ylabel("iced_tea_sales")
#plt.plot(Rgain, lm.predict(np.reshape(Rgain, (len(Rgain), 1))), color='blue', linewidth=3)
#plt.show()

#excel = xlrd.open_workbook(filename)
#data1 = excel.sheets()[0]
#for index in range(len(COOLW[0])):
#    print(COOLW[inedx])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from PIL import Image
img = Image.open("lena.bmp")
img.rotate(45).show()
