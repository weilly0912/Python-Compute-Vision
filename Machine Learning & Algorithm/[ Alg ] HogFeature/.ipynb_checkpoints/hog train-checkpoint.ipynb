# %%
import cv2
import numpy as np
import math
import matplotlib.pyplot as plt


class Hog_descriptor():
    def __init__(self, img, cell_size=16, bin_size=8):
        self.img = img
        self.img = np.sqrt(img / float(np.max(img)))
        self.img = self.img * 255
        self.cell_size = cell_size
        self.bin_size = bin_size
        self.angle_unit = 360 / self.bin_size
        #assert type(self.bin_size) == int, "bin_size should be integer,"
        #assert type(self.cell_size) == int, "cell_size should be integer,"
        #assert type(self.angle_unit) == int, "bin_size should be divisible by 360"

    def extract(self):
        height, width = self.img.shape
        gradient_magnitude, gradient_angle = self.global_gradient()
        gradient_magnitude = abs(gradient_magnitude)
        Hs = round(height / self.cell_size)
        Ws = round(width  / self.cell_size)
        cell_gradient_vector = np.zeros((Hs, Ws, self.bin_size))
        for i in range(cell_gradient_vector.shape[0]):
            for j in range(cell_gradient_vector.shape[1]):
                cell_magnitude = gradient_magnitude[i * self.cell_size:(i + 1) * self.cell_size,
                                 j * self.cell_size:(j + 1) * self.cell_size]
                cell_angle = gradient_angle[i * self.cell_size:(i + 1) * self.cell_size,
                             j * self.cell_size:(j + 1) * self.cell_size]
                cell_gradient_vector[i][j] = self.cell_gradient(cell_magnitude, cell_angle)

        hog_image = self.render_gradient(np.zeros([height, width]), cell_gradient_vector)
        hog_vector = []
        for i in range(cell_gradient_vector.shape[0] - 1):
            for j in range(cell_gradient_vector.shape[1] - 1):
                block_vector = []
                block_vector.extend(cell_gradient_vector[i][j])
                block_vector.extend(cell_gradient_vector[i][j + 1])
                block_vector.extend(cell_gradient_vector[i + 1][j])
                block_vector.extend(cell_gradient_vector[i + 1][j + 1])
                mag = lambda vector: math.sqrt(sum(i ** 2 for i in vector))
                magnitude = mag(block_vector)
                if magnitude != 0:
                    normalize = lambda block_vector, magnitude: [element / magnitude for element in block_vector]
                    block_vector = normalize(block_vector, magnitude)
                hog_vector.append(block_vector)
        return hog_vector, hog_image

    def global_gradient(self):
        gradient_values_x = cv2.Sobel(self.img, cv2.CV_64F, 1, 0, ksize=5)
        gradient_values_y = cv2.Sobel(self.img, cv2.CV_64F, 0, 1, ksize=5)
        gradient_magnitude = cv2.addWeighted(gradient_values_x, 0.5, gradient_values_y, 0.5, 0)
        gradient_angle = cv2.phase(gradient_values_x, gradient_values_y, angleInDegrees=True)
        return gradient_magnitude, gradient_angle

    def cell_gradient(self, cell_magnitude, cell_angle):
        orientation_centers = [0] * self.bin_size
        for i in range(cell_magnitude.shape[0]):
            for j in range(cell_magnitude.shape[1]):
                gradient_strength = cell_magnitude[i][j]
                gradient_angle = cell_angle[i][j]
                min_angle, max_angle, mod = self.get_closest_bins(gradient_angle)
                orientation_centers[min_angle] += (gradient_strength * (1 - (mod / self.angle_unit)))
                orientation_centers[max_angle] += (gradient_strength * (mod / self.angle_unit))
        return orientation_centers

    def get_closest_bins(self, gradient_angle):
        idx = int(gradient_angle / self.angle_unit)
        mod = gradient_angle % self.angle_unit
        if idx == self.bin_size:
            return idx - 1, (idx) % self.bin_size, mod
        return idx, (idx + 1) % self.bin_size, mod

    def render_gradient(self, image, cell_gradient):
        cell_width = self.cell_size / 2
        max_mag = np.array(cell_gradient).max()
        for x in range(cell_gradient.shape[0]):
            for y in range(cell_gradient.shape[1]):
                cell_grad = cell_gradient[x][y]
                cell_grad /= max_mag
                angle = 0
                angle_gap = self.angle_unit
                for magnitude in cell_grad:
                    angle_radian = math.radians(angle)
                    x1 = int(x * self.cell_size + magnitude * cell_width * math.cos(angle_radian))
                    y1 = int(y * self.cell_size + magnitude * cell_width * math.sin(angle_radian))
                    x2 = int(x * self.cell_size - magnitude * cell_width * math.cos(angle_radian))
                    y2 = int(y * self.cell_size - magnitude * cell_width * math.sin(angle_radian))
                    cv2.line(image, (y1, x1), (y2, x2), int(255 * math.sqrt(magnitude)))
                    angle += angle_gap
        return image

img = cv2.imread('D:\Python\HogFeature\PedestranDetectLibrary\TestImage\picture1.png', cv2.IMREAD_GRAYSCALE)
hog = Hog_descriptor(img, cell_size=8, bin_size=8)
vector, image = hog.extract()
plt.imshow(image, cmap=plt.cm.gray)
plt.show()

plt.imshow(img, cmap=plt.cm.gray)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as n
import cv2

from skimage import data, color, feature
import skimage.data

image = color.rgb2gray(cv2.imread('D:\Python\HogFeature\PedestranDetectLibrary\TestImage\pd1.png', cv2.IMREAD_GRAYSCALE))
#image = color.rgb2gray(data.checkerboard())

orientations = 8
pixels_per_cell=(8, 8)
cells_per_block=(4, 4)
hog_vec, hog_vis = feature.hog(image,orientations,pixels_per_cell, cells_per_block,visualise=True)

fig, ax = plt.subplots(1, 2, figsize=(12, 6),subplot_kw=dict(xticks=[], yticks=[]))
ax[0].imshow(image, cmap='gray')
ax[0].set_title('input image')

ax[1].imshow(hog_vis)
ax[1].set_title('visualization of HOG features');

# %%
import os
import sys
import cv2
import logging
import numpy as np

def logger_init():
    '''
    自定义python的日志信息打印配置
    :return logger: 日志信息打印模块
    '''

    # 获取logger实例，如果参数为空则返回root logger
    logger = logging.getLogger("PedestranDetect")

    # 指定logger输出格式
    formatter = logging.Formatter('%(asctime)s %(levelname)-8s: %(message)s')

    # 文件日志
    # file_handler = logging.FileHandler("test.log")
    # file_handler.setFormatter(formatter)  # 可以通过setFormatter指定输出格式

    # 控制台日志
    console_handler = logging.StreamHandler(sys.stdout)
    console_handler.formatter = formatter  # 也可以直接给formatter赋值

    # 为logger添加的日志处理器
    # logger.addHandler(file_handler)
    logger.addHandler(console_handler)

    # 指定日志的最低输出级别，默认为WARN级别
    logger.setLevel(logging.INFO)

    return logger

def load_data_set(logger):
    '''
    导入数据集
    :param logger: 日志信息打印模块
    :return pos: 正样本文件名的列表
    :return neg: 负样本文件名的列表
    :return test: 测试数据集文件名的列表。
    '''
    logger.info('Checking data path!')
    pwd = os.getcwd()
    logger.info('Current path is:{}'.format(pwd))

    # 提取正样本
    pos_dir = os.path.join(pwd, 'Positive')
    if os.path.exists(pos_dir):
        logger.info('Positive data path is:{}'.format(pos_dir))
        pos = os.listdir(pos_dir)
        logger.info('Positive samples number:{}'.format(len(pos)))

    # 提取负样本
    neg_dir = os.path.join(pwd, 'Negative')
    if os.path.exists(neg_dir):
        logger.info('Negative data path is:{}'.format(neg_dir))
        neg = os.listdir(neg_dir)
        logger.info('Negative samples number:{}'.format(len(neg)))

    # 提取测试集
    test_dir = os.path.join(pwd, 'TestData')
    if os.path.exists(test_dir):
        logger.info('Test data path is:{}'.format(test_dir))
        test = os.listdir(test_dir)
        logger.info('Test samples number:{}'.format(len(test)))

    return pos, neg, test

def load_train_samples(pos, neg):
    '''
    合并正样本pos和负样本pos，创建训练数据集和对应的标签集
    :param pos: 正样本文件名列表
    :param neg: 负样本文件名列表
    :return samples: 合并后的训练样本文件名列表
    :return labels: 对应训练样本的标签列表
    '''
    pwd = os.getcwd()
    pos_dir = os.path.join(pwd, 'Positive')
    neg_dir = os.path.join(pwd, 'Negative')

    samples = []
    labels = []
    for f in pos:
        file_path = os.path.join(pos_dir, f)
        if os.path.exists(file_path):
            samples.append(file_path)
            labels.append(1.)

    for f in neg:
        file_path = os.path.join(neg_dir, f)
        if os.path.exists(file_path):
            samples.append(file_path)
            labels.append(-1.)

    # labels 要转换成numpy数组，类型为np.int32
    labels = np.int32(labels)
    labels_len = len(pos) + len(neg)
    labels = np.resize(labels, (labels_len, 1))

    return samples, labels

def extract_hog(samples, logger):
    '''
    从训练数据集中提取HOG特征，并返回
    :param samples: 训练数据集
    :param logger: 日志信息打印模块
    :return train: 从训练数据集中提取的HOG特征
    '''
    train = []
    logger.info('Extracting HOG Descriptors...')
    num = 0.
    total = len(samples)
    for f in samples:
        num += 1.
        logger.info('Processing {} {:2.1f}%'.format(f, num/total*100))
        hog = cv2.HOGDescriptor((64,128), (16,16), (8,8), (8,8), 9)
        # hog = cv2.HOGDescriptor()
        img = cv2.imread(f, -1)
        img = cv2.resize(img, (64,128))
        descriptors = hog.compute(img)
        logger.info('hog feature descriptor size: {}'.format(descriptors.shape))    # (3780, 1)
        train.append(descriptors)

    train = np.float32(train)
    train = np.resize(train, (total, 3780))

    return train

def get_svm_detector(svm):
    '''
    导出可以用于cv2.HOGDescriptor()的SVM检测器，实质上是训练好的SVM的支持向量和rho参数组成的列表
    :param svm: 训练好的SVM分类器
    :return: SVM的支持向量和rho参数组成的列表，可用作cv2.HOGDescriptor()的SVM检测器
    '''
    sv = svm.getSupportVectors()
    rho, _, _ = svm.getDecisionFunction(0)
    sv = np.transpose(sv)
    return np.append(sv, [[-rho]], 0)

def train_svm(train, labels, logger):
    '''
    训练SVM分类器
    :param train: 训练数据集
    :param labels: 对应训练集的标签
    :param logger: 日志信息打印模块
    :return: SVM检测器（注意：opencv的hogdescriptor中的svm不能直接用opencv的svm模型，而是要导出对应格式的数组）
    '''
    logger.info('Configuring SVM classifier.')
    svm = cv2.ml.SVM_create()
    svm.setCoef0(0.0)
    svm.setDegree(3)
    criteria = (cv2.TERM_CRITERIA_MAX_ITER + cv2.TERM_CRITERIA_EPS, 1000, 1e-3)
    svm.setTermCriteria(criteria)
    svm.setGamma(0)
    svm.setKernel(cv2.ml.SVM_LINEAR)
    svm.setNu(0.5)
    svm.setP(0.1)  # for EPSILON_SVR, epsilon in loss function?
    svm.setC(0.01)  # From paper, soft classifier
    svm.setType(cv2.ml.SVM_EPS_SVR)

    logger.info('Starting training svm.')
    svm.train(train, cv2.ml.ROW_SAMPLE, labels)
    logger.info('Training done.')

    pwd = os.getcwd()
    model_path = os.path.join(pwd, 'svm.xml')
    svm.save(model_path)
    logger.info('Trained SVM classifier is saved as: {}'.format(model_path))

    return get_svm_detector(svm)

def test_hog_detect(test, svm_detector, logger):
    '''
    导入测试集，测试结果
    :param test: 测试数据集
    :param svm_detector: 用于HOGDescriptor的SVM检测器
    :param logger: 日志信息打印模块
    :return: 无
    '''
    hog = cv2.HOGDescriptor()
    hog.setSVMDetector(svm_detector)
    # opencv自带的训练好了的分类器
    # hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
    pwd = os.getcwd()
    test_dir = os.path.join(pwd, 'TestData')
    cv2.namedWindow('Detect')
    for f in test:
        file_path = os.path.join(test_dir, f)
        logger.info('Processing {}'.format(file_path))
        img = cv2.imread(file_path)
        rects, _ = hog.detectMultiScale(img, winStride=(4,4), padding=(8,8), scale=1.05)
        for (x,y,w,h) in rects:
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,0,255), 2)
        cv2.imshow('Detect', img)
        c = cv2.waitKey(0) & 0xff
        if c == 27:
            break
    cv2.destroyAllWindows()


if __name__ == '__main__':
    logger = logger_init()
    pos, neg, test = load_data_set(logger=logger)
    samples, labels = load_train_samples(pos, neg)
    train = extract_hog(samples, logger=logger)
    logger.info('Size of feature vectors of samples: {}'.format(train.shape))
    logger.info('Size of labels of samples: {}'.format(labels.shape))
    svm_detector = train_svm(train, labels, logger=logger)
    test_hog_detect(test, svm_detector, logger)

# %%
#參考文獻
#https://blog.csdn.net/u010682375/article/details/78044999
#https://blog.csdn.net/hongbin_xu/article/details/79845290
#SVM = data = HOG feature data of number, but Hog feature isnt equal as nxm

#https://blog.csdn.net/wjb820728252/article/details/78395092

# %%
#Order weilly
import os
import sys
import cv2
import logging
import numpy as np

windows_W = 64
windows_H = 128
block_W = 4
block_H = 4
blockStride_W = 2
blockStride_H = 2
cell_W = 8
cell_H = 8
bins = 8

def logger_init():
    '''
    自定义python的日志信息打印配置
    :return logger: 日志信息打印模块
    '''

    # 获取logger实例，如果参数为空则返回root logger
    logger = logging.getLogger("PedestranDetect")

    # 指定logger输出格式
    formatter = logging.Formatter('%(asctime)s %(levelname)-8s: %(message)s')

    # 文件日志
    # file_handler = logging.FileHandler("test.log")
    # file_handler.setFormatter(formatter)  # 可以通过setFormatter指定输出格式

    # 控制台日志
    console_handler = logging.StreamHandler(sys.stdout)
    console_handler.formatter = formatter  # 也可以直接给formatter赋值

    # 为logger添加的日志处理器
    # logger.addHandler(file_handler)
    logger.addHandler(console_handler)

    # 指定日志的最低输出级别，默认为WARN级别
    logger.setLevel(logging.INFO)

    return logger

def load_data_set(logger):
    '''
    导入数据集
    :param logger: 日志信息打印模块
    :return pos: 正样本文件名的列表
    :return neg: 负样本文件名的列表
    :return test: 测试数据集文件名的列表。
    '''
    logger.info('Checking data path!')
    pwd = os.getcwd()
    logger.info('Current path is:{}'.format(pwd))

    # 提取正样本
    pos_dir = os.path.join(pwd, 'Positive')
    if os.path.exists(pos_dir):
        logger.info('Positive data path is:{}'.format(pos_dir))
        pos = os.listdir(pos_dir)
        logger.info('Positive samples number:{}'.format(len(pos)))

    # 提取负样本
    neg_dir = os.path.join(pwd, 'Negative')
    if os.path.exists(neg_dir):
        logger.info('Negative data path is:{}'.format(neg_dir))
        neg = os.listdir(neg_dir)
        logger.info('Negative samples number:{}'.format(len(neg)))

    # 提取测试集
    test_dir = os.path.join(pwd, 'TestData')
    if os.path.exists(test_dir):
        logger.info('Test data path is:{}'.format(test_dir))
        test = os.listdir(test_dir)
        logger.info('Test samples number:{}'.format(len(test)))

    return pos, neg, test

def load_train_samples(pos, neg):
    '''
    合并正样本pos和负样本pos，创建训练数据集和对应的标签集
    :param pos: 正样本文件名列表
    :param neg: 负样本文件名列表
    :return samples: 合并后的训练样本文件名列表
    :return labels: 对应训练样本的标签列表
    '''
    pwd = os.getcwd()
    pos_dir = os.path.join(pwd, 'Positive')
    neg_dir = os.path.join(pwd, 'Negative')

    samples = []
    labels = []
    for f in pos:
        file_path = os.path.join(pos_dir, f)
        if os.path.exists(file_path):
            samples.append(file_path)
            labels.append(1.)

    for f in neg:
        file_path = os.path.join(neg_dir, f)
        if os.path.exists(file_path):
            samples.append(file_path)
            labels.append(-1.)

    # labels 要转换成numpy数组，类型为np.int32
    labels = np.int32(labels)
    labels_len = len(pos) + len(neg)
    labels = np.resize(labels, (labels_len, 1))

    return samples, labels

def extract_hog(samples, logger):
    '''
    从训练数据集中提取HOG特征，并返回
    :param samples: 训练数据集
    :param logger: 日志信息打印模块
    :return train: 从训练数据集中提取的HOG特征
    ''' 
    #hog
    train = []
    logger.info('Extracting HOG Descriptors...')
    num = 0.
    total = len(samples)
    for f in samples:
        num += 1.
        logger.info('Processing {} {:2.1f}%'.format(f, num/total*100))
        hog = cv2.HOGDescriptor((windows_W,windows_H), (block_W,block_H), (blockStride_W,blockStride_H), (cell_W,cell_H), bins)
        # hog = cv2.HOGDescriptor()
        img = cv2.imread(f, -1)
        img = cv2.resize(img, (windows_W,windows_H))
        descriptors = hog.compute(img)
        logger.info('hog feature descriptor size: {}'.format(descriptors.shape))    # (3720, 1)
        train.append(descriptors)

    train = np.float32(train)
    train = np.resize(train, (total,15624))

    return train

def get_svm_detector(svm):
    '''
    导出可以用于cv2.HOGDescriptor()的SVM检测器，实质上是训练好的SVM的支持向量和rho参数组成的列表
    :param svm: 训练好的SVM分类器
    :return: SVM的支持向量和rho参数组成的列表，可用作cv2.HOGDescriptor()的SVM检测器
    '''
    sv = svm.getSupportVectors()
    rho, _, _ = svm.getDecisionFunction(0)
    sv = np.transpose(sv)
    return np.append(sv, [[-rho]], 0)

def train_svm(train, labels, logger):
    '''
    训练SVM分类器
    :param train: 训练数据集
    :param labels: 对应训练集的标签
    :param logger: 日志信息打印模块
    :return: SVM检测器（注意：opencv的hogdescriptor中的svm不能直接用opencv的svm模型，而是要导出对应格式的数组）
    '''
    logger.info('Configuring SVM classifier.')
    svm = cv2.ml.SVM_create()
    svm.setCoef0(0.0)
    svm.setDegree(3)
    criteria = (cv2.TERM_CRITERIA_MAX_ITER + cv2.TERM_CRITERIA_EPS, 1000, 1e-3)
    svm.setTermCriteria(criteria)
    svm.setGamma(0)
    svm.setKernel(cv2.ml.SVM_LINEAR)
    svm.setNu(0.5)
    svm.setP(0.1)  # for EPSILON_SVR, epsilon in loss function?
    svm.setC(0.01)  # From paper, soft classifier
    svm.setType(cv2.ml.SVM_EPS_SVR)

    logger.info('Starting training svm.')
    svm.train(train, cv2.ml.ROW_SAMPLE, labels)
    logger.info('Training done.')

    pwd = os.getcwd()
    model_path = os.path.join(pwd, 'svm_hog.xml')
    svm.save(model_path)
    #logger.info('Trained SVM classifier is saved as: {}'.format(model_path))

    return get_svm_detector(svm)

def test_hog_detect(test, svm_detector, logger):
    '''
    导入测试集，测试结果
    :param test: 测试数据集
    :param svm_detector: 用于HOGDescriptor的SVM检测器
    :param logger: 日志信息打印模块
    :return: 无
    '''

    hog = cv2.HOGDescriptor((windows_W,windows_H), (block_W,block_H), (blockStride_W,blockStride_H), (cell_W,cell_H), bins)
    hog.setSVMDetector(svm_detector)
    # opencv自带的训练好了的分类器
    # hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
    pwd = os.getcwd()
    test_dir = os.path.join(pwd, 'TestData')
    cv2.namedWindow('Detect')
    for f in test:
        file_path = os.path.join(test_dir, f)
        logger.info('Processing {}'.format(file_path))
        img = cv2.imread(file_path)
        rects, _ = hog.detectMultiScale(img, winStride=(blockStride_W,blockStride_H), padding=(8,8), scale=1.05)
        for (x,y,w,h) in rects:
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,0,255), 2)
        cv2.imshow('Detect', img)
        c = cv2.waitKey(0) & 0xff
        if c == 27:
            break
    cv2.destroyAllWindows()


if __name__ == '__main__':
    logger = logger_init()
    pos, neg, test = load_data_set(logger=logger)
    samples, labels = load_train_samples(pos, neg)
    train = extract_hog(samples, logger=logger)
    logger.info('Size of feature vectors of samples: {}'.format(train.shape))
    logger.info('Size of labels of samples: {}'.format(labels.shape))
    svm_detector = train_svm(train, labels, logger=logger)
    test_hog_detect(test, svm_detector, logger)
# Out:
# 2019-07-29 16:30:34,635 INFO    : Checking data path!
# 2019-07-29 16:30:34,636 INFO    : Current path is:D:\Python\HogFeature
# 2019-07-29 16:30:34,637 INFO    : Positive data path is:D:\Python\HogFeature\Positive
# 2019-07-29 16:30:34,640 INFO    : Positive samples number:924
# 2019-07-29 16:30:34,641 INFO    : Negative data path is:D:\Python\HogFeature\Negative
# 2019-07-29 16:30:34,643 INFO    : Negative samples number:924
# 2019-07-29 16:30:34,644 INFO    : Test data path is:D:\Python\HogFeature\TestData
# 2019-07-29 16:30:34,646 INFO    : Test samples number:179
# 2019-07-29 16:30:34,730 INFO    : Extracting HOG Descriptors...
# 2019-07-29 16:30:34,731 INFO    : Processing D:\Python\HogFeature\Positive\per00001.ppm 0.1%
# 2019-07-29 16:30:34,733 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,734 INFO    : Processing D:\Python\HogFeature\Positive\per00002.ppm 0.1%
# 2019-07-29 16:30:34,736 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,737 INFO    : Processing D:\Python\HogFeature\Positive\per00003.ppm 0.2%
# 2019-07-29 16:30:34,738 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,739 INFO    : Processing D:\Python\HogFeature\Positive\per00004.ppm 0.2%
# 2019-07-29 16:30:34,741 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,742 INFO    : Processing D:\Python\HogFeature\Positive\per00005.ppm 0.3%
# 2019-07-29 16:30:34,744 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,745 INFO    : Processing D:\Python\HogFeature\Positive\per00006.ppm 0.3%
# 2019-07-29 16:30:34,747 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,748 INFO    : Processing D:\Python\HogFeature\Positive\per00007.ppm 0.4%
# 2019-07-29 16:30:34,751 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,752 INFO    : Processing D:\Python\HogFeature\Positive\per00008.ppm 0.4%
# 2019-07-29 16:30:34,753 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,755 INFO    : Processing D:\Python\HogFeature\Positive\per00009.ppm 0.5%
# 2019-07-29 16:30:34,757 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,757 INFO    : Processing D:\Python\HogFeature\Positive\per00010.ppm 0.5%
# 2019-07-29 16:30:34,759 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,760 INFO    : Processing D:\Python\HogFeature\Positive\per00011.ppm 0.6%
# 2019-07-29 16:30:34,762 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,763 INFO    : Processing D:\Python\HogFeature\Positive\per00012.ppm 0.6%
# 2019-07-29 16:30:34,765 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,766 INFO    : Processing D:\Python\HogFeature\Positive\per00013.ppm 0.7%
# 2019-07-29 16:30:34,768 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,769 INFO    : Processing D:\Python\HogFeature\Positive\per00014.ppm 0.8%
# 2019-07-29 16:30:34,771 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,771 INFO    : Processing D:\Python\HogFeature\Positive\per00015.ppm 0.8%
# 2019-07-29 16:30:34,774 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,774 INFO    : Processing D:\Python\HogFeature\Positive\per00016.ppm 0.9%
# 2019-07-29 16:30:34,777 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,778 INFO    : Processing D:\Python\HogFeature\Positive\per00017.ppm 0.9%
# 2019-07-29 16:30:34,780 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,781 INFO    : Processing D:\Python\HogFeature\Positive\per00018.ppm 1.0%
# 2019-07-29 16:30:34,782 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,783 INFO    : Processing D:\Python\HogFeature\Positive\per00019.ppm 1.0%
# 2019-07-29 16:30:34,784 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,785 INFO    : Processing D:\Python\HogFeature\Positive\per00020.ppm 1.1%
# 2019-07-29 16:30:34,787 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,788 INFO    : Processing D:\Python\HogFeature\Positive\per00021.ppm 1.1%
# 2019-07-29 16:30:34,790 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,791 INFO    : Processing D:\Python\HogFeature\Positive\per00022.ppm 1.2%
# 2019-07-29 16:30:34,793 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,794 INFO    : Processing D:\Python\HogFeature\Positive\per00023.ppm 1.2%
# 2019-07-29 16:30:34,796 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,797 INFO    : Processing D:\Python\HogFeature\Positive\per00024.ppm 1.3%
# 2019-07-29 16:30:34,799 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,800 INFO    : Processing D:\Python\HogFeature\Positive\per00025.ppm 1.4%
# 2019-07-29 16:30:34,803 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,804 INFO    : Processing D:\Python\HogFeature\Positive\per00026.ppm 1.4%
# 2019-07-29 16:30:34,806 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,806 INFO    : Processing D:\Python\HogFeature\Positive\per00027.ppm 1.5%
# 2019-07-29 16:30:34,808 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,810 INFO    : Processing D:\Python\HogFeature\Positive\per00028.ppm 1.5%
# 2019-07-29 16:30:34,811 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,812 INFO    : Processing D:\Python\HogFeature\Positive\per00029.ppm 1.6%
# 2019-07-29 16:30:34,814 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,815 INFO    : Processing D:\Python\HogFeature\Positive\per00030.ppm 1.6%
# 2019-07-29 16:30:34,817 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,818 INFO    : Processing D:\Python\HogFeature\Positive\per00031.ppm 1.7%
# 2019-07-29 16:30:34,819 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,820 INFO    : Processing D:\Python\HogFeature\Positive\per00032.ppm 1.7%
# 2019-07-29 16:30:34,821 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,822 INFO    : Processing D:\Python\HogFeature\Positive\per00033.ppm 1.8%
# 2019-07-29 16:30:34,823 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,824 INFO    : Processing D:\Python\HogFeature\Positive\per00034.ppm 1.8%
# 2019-07-29 16:30:34,826 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,826 INFO    : Processing D:\Python\HogFeature\Positive\per00035.ppm 1.9%
# 2019-07-29 16:30:34,828 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,829 INFO    : Processing D:\Python\HogFeature\Positive\per00036.ppm 1.9%
# 2019-07-29 16:30:34,830 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,831 INFO    : Processing D:\Python\HogFeature\Positive\per00037.ppm 2.0%
# 2019-07-29 16:30:34,833 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,833 INFO    : Processing D:\Python\HogFeature\Positive\per00038.ppm 2.1%
# 2019-07-29 16:30:34,835 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,836 INFO    : Processing D:\Python\HogFeature\Positive\per00039.ppm 2.1%
# 2019-07-29 16:30:34,839 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,840 INFO    : Processing D:\Python\HogFeature\Positive\per00040.ppm 2.2%
# 2019-07-29 16:30:34,843 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,844 INFO    : Processing D:\Python\HogFeature\Positive\per00041.ppm 2.2%
# 2019-07-29 16:30:34,845 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,846 INFO    : Processing D:\Python\HogFeature\Positive\per00042.ppm 2.3%
# 2019-07-29 16:30:34,847 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,848 INFO    : Processing D:\Python\HogFeature\Positive\per00043.ppm 2.3%
# 2019-07-29 16:30:34,850 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,850 INFO    : Processing D:\Python\HogFeature\Positive\per00044.ppm 2.4%
# 2019-07-29 16:30:34,852 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,852 INFO    : Processing D:\Python\HogFeature\Positive\per00045.ppm 2.4%
# 2019-07-29 16:30:34,854 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,854 INFO    : Processing D:\Python\HogFeature\Positive\per00046.ppm 2.5%
# 2019-07-29 16:30:34,856 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,857 INFO    : Processing D:\Python\HogFeature\Positive\per00047.ppm 2.5%
# 2019-07-29 16:30:34,859 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,860 INFO    : Processing D:\Python\HogFeature\Positive\per00048.ppm 2.6%
# 2019-07-29 16:30:34,862 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,863 INFO    : Processing D:\Python\HogFeature\Positive\per00049.ppm 2.7%
# 2019-07-29 16:30:34,864 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,865 INFO    : Processing D:\Python\HogFeature\Positive\per00050.ppm 2.7%
# 2019-07-29 16:30:34,866 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,867 INFO    : Processing D:\Python\HogFeature\Positive\per00051.ppm 2.8%
# 2019-07-29 16:30:34,869 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,870 INFO    : Processing D:\Python\HogFeature\Positive\per00052.ppm 2.8%
# 2019-07-29 16:30:34,872 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,873 INFO    : Processing D:\Python\HogFeature\Positive\per00053.ppm 2.9%
# 2019-07-29 16:30:34,875 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,876 INFO    : Processing D:\Python\HogFeature\Positive\per00054.ppm 2.9%
# 2019-07-29 16:30:34,879 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,879 INFO    : Processing D:\Python\HogFeature\Positive\per00055.ppm 3.0%
# 2019-07-29 16:30:34,881 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,882 INFO    : Processing D:\Python\HogFeature\Positive\per00056.ppm 3.0%
# 2019-07-29 16:30:34,884 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,885 INFO    : Processing D:\Python\HogFeature\Positive\per00057.ppm 3.1%
# 2019-07-29 16:30:34,887 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,888 INFO    : Processing D:\Python\HogFeature\Positive\per00058.ppm 3.1%
# 2019-07-29 16:30:34,889 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,890 INFO    : Processing D:\Python\HogFeature\Positive\per00059.ppm 3.2%
# 2019-07-29 16:30:34,892 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,893 INFO    : Processing D:\Python\HogFeature\Positive\per00060.ppm 3.2%
# 2019-07-29 16:30:34,895 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,895 INFO    : Processing D:\Python\HogFeature\Positive\per00061.ppm 3.3%
# 2019-07-29 16:30:34,897 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,898 INFO    : Processing D:\Python\HogFeature\Positive\per00062.ppm 3.4%
# 2019-07-29 16:30:34,900 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,900 INFO    : Processing D:\Python\HogFeature\Positive\per00063.ppm 3.4%
# 2019-07-29 16:30:34,902 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,902 INFO    : Processing D:\Python\HogFeature\Positive\per00064.ppm 3.5%
# 2019-07-29 16:30:34,904 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,905 INFO    : Processing D:\Python\HogFeature\Positive\per00065.ppm 3.5%
# 2019-07-29 16:30:34,906 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,907 INFO    : Processing D:\Python\HogFeature\Positive\per00066.ppm 3.6%
# 2019-07-29 16:30:34,909 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,910 INFO    : Processing D:\Python\HogFeature\Positive\per00067.ppm 3.6%
# 2019-07-29 16:30:34,911 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,912 INFO    : Processing D:\Python\HogFeature\Positive\per00068.ppm 3.7%
# 2019-07-29 16:30:34,914 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,915 INFO    : Processing D:\Python\HogFeature\Positive\per00069.ppm 3.7%
# 2019-07-29 16:30:34,917 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,918 INFO    : Processing D:\Python\HogFeature\Positive\per00070.ppm 3.8%
# 2019-07-29 16:30:34,920 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,921 INFO    : Processing D:\Python\HogFeature\Positive\per00071.ppm 3.8%
# 2019-07-29 16:30:34,922 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,923 INFO    : Processing D:\Python\HogFeature\Positive\per00072.ppm 3.9%
# 2019-07-29 16:30:34,924 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,925 INFO    : Processing D:\Python\HogFeature\Positive\per00073.ppm 4.0%
# 2019-07-29 16:30:34,927 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,928 INFO    : Processing D:\Python\HogFeature\Positive\per00074.ppm 4.0%
# 2019-07-29 16:30:34,929 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,930 INFO    : Processing D:\Python\HogFeature\Positive\per00075.ppm 4.1%
# 2019-07-29 16:30:34,931 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,932 INFO    : Processing D:\Python\HogFeature\Positive\per00076.ppm 4.1%
# 2019-07-29 16:30:34,934 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,935 INFO    : Processing D:\Python\HogFeature\Positive\per00077.ppm 4.2%
# 2019-07-29 16:30:34,936 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,937 INFO    : Processing D:\Python\HogFeature\Positive\per00078.ppm 4.2%
# 2019-07-29 16:30:34,938 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,939 INFO    : Processing D:\Python\HogFeature\Positive\per00079.ppm 4.3%
# 2019-07-29 16:30:34,941 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,942 INFO    : Processing D:\Python\HogFeature\Positive\per00080.ppm 4.3%
# 2019-07-29 16:30:34,943 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,944 INFO    : Processing D:\Python\HogFeature\Positive\per00081.ppm 4.4%
# 2019-07-29 16:30:34,945 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,946 INFO    : Processing D:\Python\HogFeature\Positive\per00082.ppm 4.4%
# 2019-07-29 16:30:34,947 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,948 INFO    : Processing D:\Python\HogFeature\Positive\per00083.ppm 4.5%
# 2019-07-29 16:30:34,949 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,950 INFO    : Processing D:\Python\HogFeature\Positive\per00084.ppm 4.5%
# 2019-07-29 16:30:34,952 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,952 INFO    : Processing D:\Python\HogFeature\Positive\per00085.ppm 4.6%
# 2019-07-29 16:30:34,954 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,954 INFO    : Processing D:\Python\HogFeature\Positive\per00086.ppm 4.7%
# 2019-07-29 16:30:34,956 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,957 INFO    : Processing D:\Python\HogFeature\Positive\per00087.ppm 4.7%
# 2019-07-29 16:30:34,958 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,959 INFO    : Processing D:\Python\HogFeature\Positive\per00088.ppm 4.8%
# 2019-07-29 16:30:34,961 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,962 INFO    : Processing D:\Python\HogFeature\Positive\per00089.ppm 4.8%
# 2019-07-29 16:30:34,964 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,965 INFO    : Processing D:\Python\HogFeature\Positive\per00090.ppm 4.9%
# 2019-07-29 16:30:34,967 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,968 INFO    : Processing D:\Python\HogFeature\Positive\per00091.ppm 4.9%
# 2019-07-29 16:30:34,970 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,971 INFO    : Processing D:\Python\HogFeature\Positive\per00092.ppm 5.0%
# 2019-07-29 16:30:34,973 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,973 INFO    : Processing D:\Python\HogFeature\Positive\per00093.ppm 5.0%
# 2019-07-29 16:30:34,976 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,977 INFO    : Processing D:\Python\HogFeature\Positive\per00094.ppm 5.1%
# 2019-07-29 16:30:34,979 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,980 INFO    : Processing D:\Python\HogFeature\Positive\per00095.ppm 5.1%
# 2019-07-29 16:30:34,982 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,983 INFO    : Processing D:\Python\HogFeature\Positive\per00096.ppm 5.2%
# 2019-07-29 16:30:34,984 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,985 INFO    : Processing D:\Python\HogFeature\Positive\per00097.ppm 5.2%
# 2019-07-29 16:30:34,987 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,988 INFO    : Processing D:\Python\HogFeature\Positive\per00098.ppm 5.3%
# 2019-07-29 16:30:34,990 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,990 INFO    : Processing D:\Python\HogFeature\Positive\per00099.ppm 5.4%
# 2019-07-29 16:30:34,993 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,993 INFO    : Processing D:\Python\HogFeature\Positive\per00100.ppm 5.4%
# 2019-07-29 16:30:34,995 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,996 INFO    : Processing D:\Python\HogFeature\Positive\per00101.ppm 5.5%
# 2019-07-29 16:30:34,998 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:34,999 INFO    : Processing D:\Python\HogFeature\Positive\per00102.ppm 5.5%
# 2019-07-29 16:30:35,001 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,002 INFO    : Processing D:\Python\HogFeature\Positive\per00103.ppm 5.6%
# 2019-07-29 16:30:35,004 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,005 INFO    : Processing D:\Python\HogFeature\Positive\per00104.ppm 5.6%
# 2019-07-29 16:30:35,008 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,008 INFO    : Processing D:\Python\HogFeature\Positive\per00105.ppm 5.7%
# 2019-07-29 16:30:35,011 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,011 INFO    : Processing D:\Python\HogFeature\Positive\per00106.ppm 5.7%
# 2019-07-29 16:30:35,013 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,014 INFO    : Processing D:\Python\HogFeature\Positive\per00107.ppm 5.8%
# 2019-07-29 16:30:35,015 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,016 INFO    : Processing D:\Python\HogFeature\Positive\per00108.ppm 5.8%
# 2019-07-29 16:30:35,019 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,019 INFO    : Processing D:\Python\HogFeature\Positive\per00109.ppm 5.9%
# 2019-07-29 16:30:35,021 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,022 INFO    : Processing D:\Python\HogFeature\Positive\per00110.ppm 6.0%
# 2019-07-29 16:30:35,023 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,024 INFO    : Processing D:\Python\HogFeature\Positive\per00111.ppm 6.0%
# 2019-07-29 16:30:35,025 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,026 INFO    : Processing D:\Python\HogFeature\Positive\per00112.ppm 6.1%
# 2019-07-29 16:30:35,028 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,029 INFO    : Processing D:\Python\HogFeature\Positive\per00113.ppm 6.1%
# 2019-07-29 16:30:35,030 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,031 INFO    : Processing D:\Python\HogFeature\Positive\per00114.ppm 6.2%
# 2019-07-29 16:30:35,033 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,033 INFO    : Processing D:\Python\HogFeature\Positive\per00115.ppm 6.2%
# 2019-07-29 16:30:35,035 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,036 INFO    : Processing D:\Python\HogFeature\Positive\per00116.ppm 6.3%
# 2019-07-29 16:30:35,038 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,039 INFO    : Processing D:\Python\HogFeature\Positive\per00117.ppm 6.3%
# 2019-07-29 16:30:35,040 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,041 INFO    : Processing D:\Python\HogFeature\Positive\per00118.ppm 6.4%
# 2019-07-29 16:30:35,042 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,044 INFO    : Processing D:\Python\HogFeature\Positive\per00119.ppm 6.4%
# 2019-07-29 16:30:35,045 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,046 INFO    : Processing D:\Python\HogFeature\Positive\per00120.ppm 6.5%
# 2019-07-29 16:30:35,047 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,048 INFO    : Processing D:\Python\HogFeature\Positive\per00121.ppm 6.5%
# 2019-07-29 16:30:35,049 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,050 INFO    : Processing D:\Python\HogFeature\Positive\per00122.ppm 6.6%
# 2019-07-29 16:30:35,053 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,054 INFO    : Processing D:\Python\HogFeature\Positive\per00123.ppm 6.7%
# 2019-07-29 16:30:35,056 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,057 INFO    : Processing D:\Python\HogFeature\Positive\per00124.ppm 6.7%
# 2019-07-29 16:30:35,060 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,062 INFO    : Processing D:\Python\HogFeature\Positive\per00125.ppm 6.8%
# 2019-07-29 16:30:35,065 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,066 INFO    : Processing D:\Python\HogFeature\Positive\per00126.ppm 6.8%
# 2019-07-29 16:30:35,068 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,068 INFO    : Processing D:\Python\HogFeature\Positive\per00127.ppm 6.9%
# 2019-07-29 16:30:35,071 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,071 INFO    : Processing D:\Python\HogFeature\Positive\per00128.ppm 6.9%
# 2019-07-29 16:30:35,073 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,075 INFO    : Processing D:\Python\HogFeature\Positive\per00129.ppm 7.0%
# 2019-07-29 16:30:35,077 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,078 INFO    : Processing D:\Python\HogFeature\Positive\per00130.ppm 7.0%
# 2019-07-29 16:30:35,081 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,081 INFO    : Processing D:\Python\HogFeature\Positive\per00131.ppm 7.1%
# 2019-07-29 16:30:35,083 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,084 INFO    : Processing D:\Python\HogFeature\Positive\per00132.ppm 7.1%
# 2019-07-29 16:30:35,086 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,086 INFO    : Processing D:\Python\HogFeature\Positive\per00133.ppm 7.2%
# 2019-07-29 16:30:35,088 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,089 INFO    : Processing D:\Python\HogFeature\Positive\per00134.ppm 7.3%
# 2019-07-29 16:30:35,090 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,091 INFO    : Processing D:\Python\HogFeature\Positive\per00135.ppm 7.3%
# 2019-07-29 16:30:35,092 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,093 INFO    : Processing D:\Python\HogFeature\Positive\per00136.ppm 7.4%
# 2019-07-29 16:30:35,096 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,097 INFO    : Processing D:\Python\HogFeature\Positive\per00137.ppm 7.4%
# 2019-07-29 16:30:35,099 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,100 INFO    : Processing D:\Python\HogFeature\Positive\per00138.ppm 7.5%
# 2019-07-29 16:30:35,102 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,103 INFO    : Processing D:\Python\HogFeature\Positive\per00139.ppm 7.5%
# 2019-07-29 16:30:35,107 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,109 INFO    : Processing D:\Python\HogFeature\Positive\per00140.ppm 7.6%
# 2019-07-29 16:30:35,112 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,113 INFO    : Processing D:\Python\HogFeature\Positive\per00141.ppm 7.6%
# 2019-07-29 16:30:35,114 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,115 INFO    : Processing D:\Python\HogFeature\Positive\per00142.ppm 7.7%
# 2019-07-29 16:30:35,116 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,117 INFO    : Processing D:\Python\HogFeature\Positive\per00143.ppm 7.7%
# 2019-07-29 16:30:35,119 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,119 INFO    : Processing D:\Python\HogFeature\Positive\per00144.ppm 7.8%
# 2019-07-29 16:30:35,121 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,122 INFO    : Processing D:\Python\HogFeature\Positive\per00145.ppm 7.8%
# 2019-07-29 16:30:35,124 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,125 INFO    : Processing D:\Python\HogFeature\Positive\per00146.ppm 7.9%
# 2019-07-29 16:30:35,128 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,128 INFO    : Processing D:\Python\HogFeature\Positive\per00147.ppm 8.0%
# 2019-07-29 16:30:35,130 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,131 INFO    : Processing D:\Python\HogFeature\Positive\per00148.ppm 8.0%
# 2019-07-29 16:30:35,133 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,134 INFO    : Processing D:\Python\HogFeature\Positive\per00149.ppm 8.1%
# 2019-07-29 16:30:35,136 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,136 INFO    : Processing D:\Python\HogFeature\Positive\per00150.ppm 8.1%
# 2019-07-29 16:30:35,138 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,139 INFO    : Processing D:\Python\HogFeature\Positive\per00151.ppm 8.2%
# 2019-07-29 16:30:35,140 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,141 INFO    : Processing D:\Python\HogFeature\Positive\per00152.ppm 8.2%
# 2019-07-29 16:30:35,143 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,144 INFO    : Processing D:\Python\HogFeature\Positive\per00153.ppm 8.3%
# 2019-07-29 16:30:35,147 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,147 INFO    : Processing D:\Python\HogFeature\Positive\per00154.ppm 8.3%
# 2019-07-29 16:30:35,149 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,149 INFO    : Processing D:\Python\HogFeature\Positive\per00155.ppm 8.4%
# 2019-07-29 16:30:35,151 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,152 INFO    : Processing D:\Python\HogFeature\Positive\per00156.ppm 8.4%
# 2019-07-29 16:30:35,153 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,153 INFO    : Processing D:\Python\HogFeature\Positive\per00157.ppm 8.5%
# 2019-07-29 16:30:35,155 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,155 INFO    : Processing D:\Python\HogFeature\Positive\per00158.ppm 8.5%
# 2019-07-29 16:30:35,157 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,158 INFO    : Processing D:\Python\HogFeature\Positive\per00159.ppm 8.6%
# 2019-07-29 16:30:35,161 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,161 INFO    : Processing D:\Python\HogFeature\Positive\per00160.ppm 8.7%
# 2019-07-29 16:30:35,163 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,163 INFO    : Processing D:\Python\HogFeature\Positive\per00161.ppm 8.7%
# 2019-07-29 16:30:35,165 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,166 INFO    : Processing D:\Python\HogFeature\Positive\per00162.ppm 8.8%
# 2019-07-29 16:30:35,167 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,168 INFO    : Processing D:\Python\HogFeature\Positive\per00163.ppm 8.8%
# 2019-07-29 16:30:35,169 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,170 INFO    : Processing D:\Python\HogFeature\Positive\per00164.ppm 8.9%
# 2019-07-29 16:30:35,172 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,172 INFO    : Processing D:\Python\HogFeature\Positive\per00165.ppm 8.9%
# 2019-07-29 16:30:35,174 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,174 INFO    : Processing D:\Python\HogFeature\Positive\per00166.ppm 9.0%
# 2019-07-29 16:30:35,177 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,178 INFO    : Processing D:\Python\HogFeature\Positive\per00167.ppm 9.0%
# 2019-07-29 16:30:35,179 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,180 INFO    : Processing D:\Python\HogFeature\Positive\per00168.ppm 9.1%
# 2019-07-29 16:30:35,181 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,182 INFO    : Processing D:\Python\HogFeature\Positive\per00169.ppm 9.1%
# 2019-07-29 16:30:35,183 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,184 INFO    : Processing D:\Python\HogFeature\Positive\per00170.ppm 9.2%
# 2019-07-29 16:30:35,185 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,186 INFO    : Processing D:\Python\HogFeature\Positive\per00171.ppm 9.3%
# 2019-07-29 16:30:35,188 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,188 INFO    : Processing D:\Python\HogFeature\Positive\per00172.ppm 9.3%
# 2019-07-29 16:30:35,190 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,191 INFO    : Processing D:\Python\HogFeature\Positive\per00173.ppm 9.4%
# 2019-07-29 16:30:35,193 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,194 INFO    : Processing D:\Python\HogFeature\Positive\per00174.ppm 9.4%
# 2019-07-29 16:30:35,196 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,196 INFO    : Processing D:\Python\HogFeature\Positive\per00175.ppm 9.5%
# 2019-07-29 16:30:35,198 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,198 INFO    : Processing D:\Python\HogFeature\Positive\per00176.ppm 9.5%
# 2019-07-29 16:30:35,200 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,201 INFO    : Processing D:\Python\HogFeature\Positive\per00177.ppm 9.6%
# 2019-07-29 16:30:35,202 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,203 INFO    : Processing D:\Python\HogFeature\Positive\per00178.ppm 9.6%
# 2019-07-29 16:30:35,205 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,205 INFO    : Processing D:\Python\HogFeature\Positive\per00179.ppm 9.7%
# 2019-07-29 16:30:35,207 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,207 INFO    : Processing D:\Python\HogFeature\Positive\per00180.ppm 9.7%
# 2019-07-29 16:30:35,210 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,211 INFO    : Processing D:\Python\HogFeature\Positive\per00181.ppm 9.8%
# 2019-07-29 16:30:35,212 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,213 INFO    : Processing D:\Python\HogFeature\Positive\per00182.ppm 9.8%
# 2019-07-29 16:30:35,214 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,215 INFO    : Processing D:\Python\HogFeature\Positive\per00183.ppm 9.9%
# 2019-07-29 16:30:35,216 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,217 INFO    : Processing D:\Python\HogFeature\Positive\per00184.ppm 10.0%
# 2019-07-29 16:30:35,218 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,219 INFO    : Processing D:\Python\HogFeature\Positive\per00185.ppm 10.0%
# 2019-07-29 16:30:35,220 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,221 INFO    : Processing D:\Python\HogFeature\Positive\per00186.ppm 10.1%
# 2019-07-29 16:30:35,223 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,223 INFO    : Processing D:\Python\HogFeature\Positive\per00187.ppm 10.1%
# 2019-07-29 16:30:35,225 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,226 INFO    : Processing D:\Python\HogFeature\Positive\per00188.ppm 10.2%
# 2019-07-29 16:30:35,229 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,229 INFO    : Processing D:\Python\HogFeature\Positive\per00189.ppm 10.2%
# 2019-07-29 16:30:35,231 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,231 INFO    : Processing D:\Python\HogFeature\Positive\per00190.ppm 10.3%
# 2019-07-29 16:30:35,233 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,233 INFO    : Processing D:\Python\HogFeature\Positive\per00191.ppm 10.3%
# 2019-07-29 16:30:35,235 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,235 INFO    : Processing D:\Python\HogFeature\Positive\per00192.ppm 10.4%
# 2019-07-29 16:30:35,236 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,237 INFO    : Processing D:\Python\HogFeature\Positive\per00193.ppm 10.4%
# 2019-07-29 16:30:35,238 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,239 INFO    : Processing D:\Python\HogFeature\Positive\per00194.ppm 10.5%
# 2019-07-29 16:30:35,240 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,241 INFO    : Processing D:\Python\HogFeature\Positive\per00195.ppm 10.6%
# 2019-07-29 16:30:35,243 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,243 INFO    : Processing D:\Python\HogFeature\Positive\per00196.ppm 10.6%
# 2019-07-29 16:30:35,245 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,246 INFO    : Processing D:\Python\HogFeature\Positive\per00197.ppm 10.7%
# 2019-07-29 16:30:35,248 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,249 INFO    : Processing D:\Python\HogFeature\Positive\per00198.ppm 10.7%
# 2019-07-29 16:30:35,250 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,251 INFO    : Processing D:\Python\HogFeature\Positive\per00199.ppm 10.8%
# 2019-07-29 16:30:35,253 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,253 INFO    : Processing D:\Python\HogFeature\Positive\per00200.ppm 10.8%
# 2019-07-29 16:30:35,255 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,255 INFO    : Processing D:\Python\HogFeature\Positive\per00201.ppm 10.9%
# 2019-07-29 16:30:35,257 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,258 INFO    : Processing D:\Python\HogFeature\Positive\per00202.ppm 10.9%
# 2019-07-29 16:30:35,261 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,262 INFO    : Processing D:\Python\HogFeature\Positive\per00203.ppm 11.0%
# 2019-07-29 16:30:35,264 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,264 INFO    : Processing D:\Python\HogFeature\Positive\per00204.ppm 11.0%
# 2019-07-29 16:30:35,266 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,266 INFO    : Processing D:\Python\HogFeature\Positive\per00205.ppm 11.1%
# 2019-07-29 16:30:35,268 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,268 INFO    : Processing D:\Python\HogFeature\Positive\per00206.ppm 11.1%
# 2019-07-29 16:30:35,270 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,270 INFO    : Processing D:\Python\HogFeature\Positive\per00207.ppm 11.2%
# 2019-07-29 16:30:35,272 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,273 INFO    : Processing D:\Python\HogFeature\Positive\per00208.ppm 11.3%
# 2019-07-29 16:30:35,276 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,277 INFO    : Processing D:\Python\HogFeature\Positive\per00209.ppm 11.3%
# 2019-07-29 16:30:35,279 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,280 INFO    : Processing D:\Python\HogFeature\Positive\per00210.ppm 11.4%
# 2019-07-29 16:30:35,281 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,282 INFO    : Processing D:\Python\HogFeature\Positive\per00211.ppm 11.4%
# 2019-07-29 16:30:35,284 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,284 INFO    : Processing D:\Python\HogFeature\Positive\per00212.ppm 11.5%
# 2019-07-29 16:30:35,286 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,287 INFO    : Processing D:\Python\HogFeature\Positive\per00213.ppm 11.5%
# 2019-07-29 16:30:35,289 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,289 INFO    : Processing D:\Python\HogFeature\Positive\per00214.ppm 11.6%
# 2019-07-29 16:30:35,291 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,293 INFO    : Processing D:\Python\HogFeature\Positive\per00215.ppm 11.6%
# 2019-07-29 16:30:35,295 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,296 INFO    : Processing D:\Python\HogFeature\Positive\per00216.ppm 11.7%
# 2019-07-29 16:30:35,298 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,298 INFO    : Processing D:\Python\HogFeature\Positive\per00217.ppm 11.7%
# 2019-07-29 16:30:35,300 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,301 INFO    : Processing D:\Python\HogFeature\Positive\per00218.ppm 11.8%
# 2019-07-29 16:30:35,303 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,304 INFO    : Processing D:\Python\HogFeature\Positive\per00219.ppm 11.9%
# 2019-07-29 16:30:35,305 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,306 INFO    : Processing D:\Python\HogFeature\Positive\per00220.ppm 11.9%
# 2019-07-29 16:30:35,307 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,309 INFO    : Processing D:\Python\HogFeature\Positive\per00221.ppm 12.0%
# 2019-07-29 16:30:35,312 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,312 INFO    : Processing D:\Python\HogFeature\Positive\per00222.ppm 12.0%
# 2019-07-29 16:30:35,314 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,314 INFO    : Processing D:\Python\HogFeature\Positive\per00223.ppm 12.1%
# 2019-07-29 16:30:35,316 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,317 INFO    : Processing D:\Python\HogFeature\Positive\per00224.ppm 12.1%
# 2019-07-29 16:30:35,318 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,319 INFO    : Processing D:\Python\HogFeature\Positive\per00225.ppm 12.2%
# 2019-07-29 16:30:35,321 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,321 INFO    : Processing D:\Python\HogFeature\Positive\per00226.ppm 12.2%
# 2019-07-29 16:30:35,323 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,324 INFO    : Processing D:\Python\HogFeature\Positive\per00227.ppm 12.3%
# 2019-07-29 16:30:35,326 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,327 INFO    : Processing D:\Python\HogFeature\Positive\per00228.ppm 12.3%
# 2019-07-29 16:30:35,329 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,329 INFO    : Processing D:\Python\HogFeature\Positive\per00229.ppm 12.4%
# 2019-07-29 16:30:35,331 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,331 INFO    : Processing D:\Python\HogFeature\Positive\per00230.ppm 12.4%
# 2019-07-29 16:30:35,333 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,333 INFO    : Processing D:\Python\HogFeature\Positive\per00231.ppm 12.5%
# 2019-07-29 16:30:35,335 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,336 INFO    : Processing D:\Python\HogFeature\Positive\per00232.ppm 12.6%
# 2019-07-29 16:30:35,337 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,338 INFO    : Processing D:\Python\HogFeature\Positive\per00233.ppm 12.6%
# 2019-07-29 16:30:35,340 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,340 INFO    : Processing D:\Python\HogFeature\Positive\per00234.ppm 12.7%
# 2019-07-29 16:30:35,341 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,342 INFO    : Processing D:\Python\HogFeature\Positive\per00235.ppm 12.7%
# 2019-07-29 16:30:35,345 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,346 INFO    : Processing D:\Python\HogFeature\Positive\per00236.ppm 12.8%
# 2019-07-29 16:30:35,347 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,348 INFO    : Processing D:\Python\HogFeature\Positive\per00237.ppm 12.8%
# 2019-07-29 16:30:35,349 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,350 INFO    : Processing D:\Python\HogFeature\Positive\per00238.ppm 12.9%
# 2019-07-29 16:30:35,353 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,354 INFO    : Processing D:\Python\HogFeature\Positive\per00239.ppm 12.9%
# 2019-07-29 16:30:35,356 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,356 INFO    : Processing D:\Python\HogFeature\Positive\per00240.ppm 13.0%
# 2019-07-29 16:30:35,358 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,360 INFO    : Processing D:\Python\HogFeature\Positive\per00241.ppm 13.0%
# 2019-07-29 16:30:35,362 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,363 INFO    : Processing D:\Python\HogFeature\Positive\per00242.ppm 13.1%
# 2019-07-29 16:30:35,365 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,366 INFO    : Processing D:\Python\HogFeature\Positive\per00243.ppm 13.1%
# 2019-07-29 16:30:35,368 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,368 INFO    : Processing D:\Python\HogFeature\Positive\per00244.ppm 13.2%
# 2019-07-29 16:30:35,370 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,370 INFO    : Processing D:\Python\HogFeature\Positive\per00245.ppm 13.3%
# 2019-07-29 16:30:35,372 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,372 INFO    : Processing D:\Python\HogFeature\Positive\per00246.ppm 13.3%
# 2019-07-29 16:30:35,374 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,375 INFO    : Processing D:\Python\HogFeature\Positive\per00247.ppm 13.4%
# 2019-07-29 16:30:35,378 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,379 INFO    : Processing D:\Python\HogFeature\Positive\per00248.ppm 13.4%
# 2019-07-29 16:30:35,382 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,382 INFO    : Processing D:\Python\HogFeature\Positive\per00249.ppm 13.5%
# 2019-07-29 16:30:35,384 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,384 INFO    : Processing D:\Python\HogFeature\Positive\per00250.ppm 13.5%
# 2019-07-29 16:30:35,386 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,386 INFO    : Processing D:\Python\HogFeature\Positive\per00251.ppm 13.6%
# 2019-07-29 16:30:35,388 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,389 INFO    : Processing D:\Python\HogFeature\Positive\per00252.ppm 13.6%
# 2019-07-29 16:30:35,391 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,392 INFO    : Processing D:\Python\HogFeature\Positive\per00253.ppm 13.7%
# 2019-07-29 16:30:35,395 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,395 INFO    : Processing D:\Python\HogFeature\Positive\per00254.ppm 13.7%
# 2019-07-29 16:30:35,397 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,397 INFO    : Processing D:\Python\HogFeature\Positive\per00255.ppm 13.8%
# 2019-07-29 16:30:35,399 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,399 INFO    : Processing D:\Python\HogFeature\Positive\per00256.ppm 13.9%
# 2019-07-29 16:30:35,401 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,401 INFO    : Processing D:\Python\HogFeature\Positive\per00257.ppm 13.9%
# 2019-07-29 16:30:35,403 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,404 INFO    : Processing D:\Python\HogFeature\Positive\per00258.ppm 14.0%
# 2019-07-29 16:30:35,406 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,406 INFO    : Processing D:\Python\HogFeature\Positive\per00259.ppm 14.0%
# 2019-07-29 16:30:35,408 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,409 INFO    : Processing D:\Python\HogFeature\Positive\per00260.ppm 14.1%
# 2019-07-29 16:30:35,412 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,413 INFO    : Processing D:\Python\HogFeature\Positive\per00261.ppm 14.1%
# 2019-07-29 16:30:35,414 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,414 INFO    : Processing D:\Python\HogFeature\Positive\per00262.ppm 14.2%
# 2019-07-29 16:30:35,416 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,416 INFO    : Processing D:\Python\HogFeature\Positive\per00263.ppm 14.2%
# 2019-07-29 16:30:35,418 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,419 INFO    : Processing D:\Python\HogFeature\Positive\per00264.ppm 14.3%
# 2019-07-29 16:30:35,420 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,421 INFO    : Processing D:\Python\HogFeature\Positive\per00265.ppm 14.3%
# 2019-07-29 16:30:35,423 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,424 INFO    : Processing D:\Python\HogFeature\Positive\per00266.ppm 14.4%
# 2019-07-29 16:30:35,426 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,427 INFO    : Processing D:\Python\HogFeature\Positive\per00267.ppm 14.4%
# 2019-07-29 16:30:35,429 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,430 INFO    : Processing D:\Python\HogFeature\Positive\per00268.ppm 14.5%
# 2019-07-29 16:30:35,431 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,432 INFO    : Processing D:\Python\HogFeature\Positive\per00269.ppm 14.6%
# 2019-07-29 16:30:35,433 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,434 INFO    : Processing D:\Python\HogFeature\Positive\per00270.ppm 14.6%
# 2019-07-29 16:30:35,435 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,436 INFO    : Processing D:\Python\HogFeature\Positive\per00271.ppm 14.7%
# 2019-07-29 16:30:35,437 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,438 INFO    : Processing D:\Python\HogFeature\Positive\per00272.ppm 14.7%
# 2019-07-29 16:30:35,439 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,440 INFO    : Processing D:\Python\HogFeature\Positive\per00273.ppm 14.8%
# 2019-07-29 16:30:35,442 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,443 INFO    : Processing D:\Python\HogFeature\Positive\per00274.ppm 14.8%
# 2019-07-29 16:30:35,446 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,447 INFO    : Processing D:\Python\HogFeature\Positive\per00275.ppm 14.9%
# 2019-07-29 16:30:35,449 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,450 INFO    : Processing D:\Python\HogFeature\Positive\per00276.ppm 14.9%
# 2019-07-29 16:30:35,452 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,453 INFO    : Processing D:\Python\HogFeature\Positive\per00277.ppm 15.0%
# 2019-07-29 16:30:35,454 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,455 INFO    : Processing D:\Python\HogFeature\Positive\per00278.ppm 15.0%
# 2019-07-29 16:30:35,456 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,457 INFO    : Processing D:\Python\HogFeature\Positive\per00279.ppm 15.1%
# 2019-07-29 16:30:35,459 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,460 INFO    : Processing D:\Python\HogFeature\Positive\per00280.ppm 15.2%
# 2019-07-29 16:30:35,462 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,463 INFO    : Processing D:\Python\HogFeature\Positive\per00281.ppm 15.2%
# 2019-07-29 16:30:35,465 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,465 INFO    : Processing D:\Python\HogFeature\Positive\per00282.ppm 15.3%
# 2019-07-29 16:30:35,467 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:35,468 INFO    : Processing D:\Python\HogFeature\Positive\per00283.ppm 15.3%
# 2019-07-29 16:30:35,470 INFO    : hog feature descriptor size: (15624, 1)
# ...
# 2019-07-29 16:30:40,164 INFO    : Processing D:\Python\HogFeature\Negative\002024.jpg 95.0%
# 2019-07-29 16:30:40,167 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,167 INFO    : Processing D:\Python\HogFeature\Negative\002025.jpg 95.0%
# 2019-07-29 16:30:40,169 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,170 INFO    : Processing D:\Python\HogFeature\Negative\002026.jpg 95.1%
# 2019-07-29 16:30:40,172 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,173 INFO    : Processing D:\Python\HogFeature\Negative\002027.jpg 95.1%
# 2019-07-29 16:30:40,176 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,177 INFO    : Processing D:\Python\HogFeature\Negative\002028.jpg 95.2%
# 2019-07-29 16:30:40,179 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,180 INFO    : Processing D:\Python\HogFeature\Negative\002029.jpg 95.2%
# 2019-07-29 16:30:40,182 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,182 INFO    : Processing D:\Python\HogFeature\Negative\002030.jpg 95.3%
# 2019-07-29 16:30:40,185 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,185 INFO    : Processing D:\Python\HogFeature\Negative\002031.jpg 95.3%
# 2019-07-29 16:30:40,187 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,188 INFO    : Processing D:\Python\HogFeature\Negative\002032.jpg 95.4%
# 2019-07-29 16:30:40,190 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,191 INFO    : Processing D:\Python\HogFeature\Negative\002033.jpg 95.5%
# 2019-07-29 16:30:40,193 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,194 INFO    : Processing D:\Python\HogFeature\Negative\002034.jpg 95.5%
# 2019-07-29 16:30:40,196 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,197 INFO    : Processing D:\Python\HogFeature\Negative\002035.jpg 95.6%
# 2019-07-29 16:30:40,199 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,200 INFO    : Processing D:\Python\HogFeature\Negative\002036.jpg 95.6%
# 2019-07-29 16:30:40,202 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,202 INFO    : Processing D:\Python\HogFeature\Negative\002037.jpg 95.7%
# 2019-07-29 16:30:40,204 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,205 INFO    : Processing D:\Python\HogFeature\Negative\002038.jpg 95.7%
# 2019-07-29 16:30:40,207 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,208 INFO    : Processing D:\Python\HogFeature\Negative\002039.jpg 95.8%
# 2019-07-29 16:30:40,211 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,212 INFO    : Processing D:\Python\HogFeature\Negative\002040.jpg 95.8%
# 2019-07-29 16:30:40,215 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,215 INFO    : Processing D:\Python\HogFeature\Negative\002041.jpg 95.9%
# 2019-07-29 16:30:40,218 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,219 INFO    : Processing D:\Python\HogFeature\Negative\002042.jpg 95.9%
# 2019-07-29 16:30:40,221 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,222 INFO    : Processing D:\Python\HogFeature\Negative\002043.jpg 96.0%
# 2019-07-29 16:30:40,225 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,226 INFO    : Processing D:\Python\HogFeature\Negative\002044.jpg 96.0%
# 2019-07-29 16:30:40,228 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,229 INFO    : Processing D:\Python\HogFeature\Negative\002045.jpg 96.1%
# 2019-07-29 16:30:40,231 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,232 INFO    : Processing D:\Python\HogFeature\Negative\002046.jpg 96.2%
# 2019-07-29 16:30:40,234 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,235 INFO    : Processing D:\Python\HogFeature\Negative\002047.jpg 96.2%
# 2019-07-29 16:30:40,237 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,238 INFO    : Processing D:\Python\HogFeature\Negative\002048.jpg 96.3%
# 2019-07-29 16:30:40,240 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,241 INFO    : Processing D:\Python\HogFeature\Negative\002049.jpg 96.3%
# 2019-07-29 16:30:40,244 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,244 INFO    : Processing D:\Python\HogFeature\Negative\002050.jpg 96.4%
# 2019-07-29 16:30:40,247 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,247 INFO    : Processing D:\Python\HogFeature\Negative\002051.jpg 96.4%
# 2019-07-29 16:30:40,249 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,250 INFO    : Processing D:\Python\HogFeature\Negative\002052.jpg 96.5%
# 2019-07-29 16:30:40,252 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,253 INFO    : Processing D:\Python\HogFeature\Negative\002053.jpg 96.5%
# 2019-07-29 16:30:40,255 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,255 INFO    : Processing D:\Python\HogFeature\Negative\002054.jpg 96.6%
# 2019-07-29 16:30:40,259 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,260 INFO    : Processing D:\Python\HogFeature\Negative\002055.jpg 96.6%
# 2019-07-29 16:30:40,262 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,263 INFO    : Processing D:\Python\HogFeature\Negative\002056.jpg 96.7%
# 2019-07-29 16:30:40,265 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,266 INFO    : Processing D:\Python\HogFeature\Negative\002057.jpg 96.8%
# 2019-07-29 16:30:40,268 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,268 INFO    : Processing D:\Python\HogFeature\Negative\002058.jpg 96.8%
# 2019-07-29 16:30:40,271 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,271 INFO    : Processing D:\Python\HogFeature\Negative\002059.jpg 96.9%
# 2019-07-29 16:30:40,274 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,275 INFO    : Processing D:\Python\HogFeature\Negative\002060.jpg 96.9%
# 2019-07-29 16:30:40,278 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,278 INFO    : Processing D:\Python\HogFeature\Negative\002061.jpg 97.0%
# 2019-07-29 16:30:40,280 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,281 INFO    : Processing D:\Python\HogFeature\Negative\002062.jpg 97.0%
# 2019-07-29 16:30:40,283 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,284 INFO    : Processing D:\Python\HogFeature\Negative\002063.jpg 97.1%
# 2019-07-29 16:30:40,285 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,286 INFO    : Processing D:\Python\HogFeature\Negative\002064.jpg 97.1%
# 2019-07-29 16:30:40,288 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,288 INFO    : Processing D:\Python\HogFeature\Negative\002065.jpg 97.2%
# 2019-07-29 16:30:40,291 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,292 INFO    : Processing D:\Python\HogFeature\Negative\002066.jpg 97.2%
# 2019-07-29 16:30:40,294 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,295 INFO    : Processing D:\Python\HogFeature\Negative\002067.jpg 97.3%
# 2019-07-29 16:30:40,297 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,298 INFO    : Processing D:\Python\HogFeature\Negative\002068.jpg 97.3%
# 2019-07-29 16:30:40,300 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,301 INFO    : Processing D:\Python\HogFeature\Negative\002069.jpg 97.4%
# 2019-07-29 16:30:40,303 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,304 INFO    : Processing D:\Python\HogFeature\Negative\002070.jpg 97.5%
# 2019-07-29 16:30:40,306 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,308 INFO    : Processing D:\Python\HogFeature\Negative\002071.jpg 97.5%
# 2019-07-29 16:30:40,310 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,311 INFO    : Processing D:\Python\HogFeature\Negative\002072.jpg 97.6%
# 2019-07-29 16:30:40,314 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,315 INFO    : Processing D:\Python\HogFeature\Negative\002073.jpg 97.6%
# 2019-07-29 16:30:40,317 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,318 INFO    : Processing D:\Python\HogFeature\Negative\002074.jpg 97.7%
# 2019-07-29 16:30:40,321 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,321 INFO    : Processing D:\Python\HogFeature\Negative\002075.jpg 97.7%
# 2019-07-29 16:30:40,325 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,326 INFO    : Processing D:\Python\HogFeature\Negative\002076.jpg 97.8%
# 2019-07-29 16:30:40,328 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,329 INFO    : Processing D:\Python\HogFeature\Negative\002077.jpg 97.8%
# 2019-07-29 16:30:40,332 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,332 INFO    : Processing D:\Python\HogFeature\Negative\002078.jpg 97.9%
# 2019-07-29 16:30:40,335 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,336 INFO    : Processing D:\Python\HogFeature\Negative\002080.jpg 97.9%
# 2019-07-29 16:30:40,338 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,339 INFO    : Processing D:\Python\HogFeature\Negative\002081.jpg 98.0%
# 2019-07-29 16:30:40,343 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,344 INFO    : Processing D:\Python\HogFeature\Negative\002082.jpg 98.1%
# 2019-07-29 16:30:40,347 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,348 INFO    : Processing D:\Python\HogFeature\Negative\002083.jpg 98.1%
# 2019-07-29 16:30:40,350 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,351 INFO    : Processing D:\Python\HogFeature\Negative\002084.jpg 98.2%
# 2019-07-29 16:30:40,353 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,354 INFO    : Processing D:\Python\HogFeature\Negative\002085.jpg 98.2%
# 2019-07-29 16:30:40,357 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,359 INFO    : Processing D:\Python\HogFeature\Negative\002086.jpg 98.3%
# 2019-07-29 16:30:40,362 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,362 INFO    : Processing D:\Python\HogFeature\Negative\002088.jpg 98.3%
# 2019-07-29 16:30:40,365 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,366 INFO    : Processing D:\Python\HogFeature\Negative\002089.jpg 98.4%
# 2019-07-29 16:30:40,368 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,369 INFO    : Processing D:\Python\HogFeature\Negative\002090.jpg 98.4%
# 2019-07-29 16:30:40,371 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,372 INFO    : Processing D:\Python\HogFeature\Negative\002091.jpg 98.5%
# 2019-07-29 16:30:40,375 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,376 INFO    : Processing D:\Python\HogFeature\Negative\002092.jpg 98.5%
# 2019-07-29 16:30:40,378 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,379 INFO    : Processing D:\Python\HogFeature\Negative\002093.jpg 98.6%
# 2019-07-29 16:30:40,382 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,382 INFO    : Processing D:\Python\HogFeature\Negative\002094.jpg 98.6%
# 2019-07-29 16:30:40,385 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,385 INFO    : Processing D:\Python\HogFeature\Negative\002095.jpg 98.7%
# 2019-07-29 16:30:40,387 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,388 INFO    : Processing D:\Python\HogFeature\Negative\002097.jpg 98.8%
# 2019-07-29 16:30:40,392 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,393 INFO    : Processing D:\Python\HogFeature\Negative\002098.jpg 98.8%
# 2019-07-29 16:30:40,396 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,397 INFO    : Processing D:\Python\HogFeature\Negative\002099.jpg 98.9%
# 2019-07-29 16:30:40,399 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,400 INFO    : Processing D:\Python\HogFeature\Negative\002100.jpg 98.9%
# 2019-07-29 16:30:40,402 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,402 INFO    : Processing D:\Python\HogFeature\Negative\002101.jpg 99.0%
# 2019-07-29 16:30:40,405 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,405 INFO    : Processing D:\Python\HogFeature\Negative\002102.jpg 99.0%
# 2019-07-29 16:30:40,409 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,410 INFO    : Processing D:\Python\HogFeature\Negative\002103.jpg 99.1%
# 2019-07-29 16:30:40,412 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,413 INFO    : Processing D:\Python\HogFeature\Negative\002104.jpg 99.1%
# 2019-07-29 16:30:40,415 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,415 INFO    : Processing D:\Python\HogFeature\Negative\002105.jpg 99.2%
# 2019-07-29 16:30:40,417 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,417 INFO    : Processing D:\Python\HogFeature\Negative\002106.jpg 99.2%
# 2019-07-29 16:30:40,419 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,420 INFO    : Processing D:\Python\HogFeature\Negative\002107.jpg 99.3%
# 2019-07-29 16:30:40,422 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,424 INFO    : Processing D:\Python\HogFeature\Negative\002108.jpg 99.4%
# 2019-07-29 16:30:40,426 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,427 INFO    : Processing D:\Python\HogFeature\Negative\002109.jpg 99.4%
# 2019-07-29 16:30:40,429 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,430 INFO    : Processing D:\Python\HogFeature\Negative\002110.jpg 99.5%
# 2019-07-29 16:30:40,432 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,432 INFO    : Processing D:\Python\HogFeature\Negative\002111.jpg 99.5%
# 2019-07-29 16:30:40,435 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,435 INFO    : Processing D:\Python\HogFeature\Negative\002112.jpg 99.6%
# 2019-07-29 16:30:40,438 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,438 INFO    : Processing D:\Python\HogFeature\Negative\002113.jpg 99.6%
# 2019-07-29 16:30:40,442 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,442 INFO    : Processing D:\Python\HogFeature\Negative\002114.jpg 99.7%
# 2019-07-29 16:30:40,445 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,446 INFO    : Processing D:\Python\HogFeature\Negative\002115.jpg 99.7%
# 2019-07-29 16:30:40,448 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,448 INFO    : Processing D:\Python\HogFeature\Negative\002116.jpg 99.8%
# 2019-07-29 16:30:40,450 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,450 INFO    : Processing D:\Python\HogFeature\Negative\002117.jpg 99.8%
# 2019-07-29 16:30:40,453 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,453 INFO    : Processing D:\Python\HogFeature\Negative\002118.jpg 99.9%
# 2019-07-29 16:30:40,455 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,457 INFO    : Processing D:\Python\HogFeature\Negative\002119.jpg 99.9%
# 2019-07-29 16:30:40,460 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,460 INFO    : Processing D:\Python\HogFeature\Negative\002120.jpg 100.0%
# 2019-07-29 16:30:40,463 INFO    : hog feature descriptor size: (15624, 1)
# 2019-07-29 16:30:40,916 INFO    : Size of feature vectors of samples: (1848, 61000)
# 2019-07-29 16:30:40,917 INFO    : Size of labels of samples: (1848, 1)
# 2019-07-29 16:30:40,918 INFO    : Configuring SVM classifier.
# 2019-07-29 16:30:40,919 INFO    : Starting training svm.
# 2019-07-29 16:32:40,985 INFO    : Training done.

# %%
test_hog_detect(test, svm_detector, logger)

# %%
import cv2
import os
import sys
import cv2
import logging
import numpy as np

windows_W = 64
windows_H = 128
block_W = 4
block_H = 4
blockStride_W = 1
blockStride_H = 1
cell_W = 4
cell_H = 4
bins = 8

def logger_init():
    '''
    自定义python的日志信息打印配置
    :return logger: 日志信息打印模块
    '''

    # 获取logger实例，如果参数为空则返回root logger
    logger = logging.getLogger("PedestranDetect")

    # 指定logger输出格式
    formatter = logging.Formatter('%(asctime)s %(levelname)-8s: %(message)s')

    # 文件日志
    # file_handler = logging.FileHandler("test.log")
    # file_handler.setFormatter(formatter)  # 可以通过setFormatter指定输出格式

    # 控制台日志
    console_handler = logging.StreamHandler(sys.stdout)
    console_handler.formatter = formatter  # 也可以直接给formatter赋值

    # 为logger添加的日志处理器
    # logger.addHandler(file_handler)
    logger.addHandler(console_handler)

    # 指定日志的最低输出级别，默认为WARN级别
    logger.setLevel(logging.INFO)

    return logger

def load_data_set(logger):
    '''
    导入数据集
    :param logger: 日志信息打印模块
    :return pos: 正样本文件名的列表
    :return neg: 负样本文件名的列表
    :return test: 测试数据集文件名的列表。
    '''
    logger.info('Checking data path!')
    pwd = os.getcwd()
    logger.info('Current path is:{}'.format(pwd))

    # 提取正样本
    pos_dir = os.path.join(pwd, 'Positive')
    if os.path.exists(pos_dir):
        logger.info('Positive data path is:{}'.format(pos_dir))
        pos = os.listdir(pos_dir)
        logger.info('Positive samples number:{}'.format(len(pos)))

    # 提取负样本
    neg_dir = os.path.join(pwd, 'Negative')
    if os.path.exists(neg_dir):
        logger.info('Negative data path is:{}'.format(neg_dir))
        neg = os.listdir(neg_dir)
        logger.info('Negative samples number:{}'.format(len(neg)))

    # 提取测试集
    test_dir = os.path.join(pwd, 'TestData')
    if os.path.exists(test_dir):
        logger.info('Test data path is:{}'.format(test_dir))
        test = os.listdir(test_dir)
        logger.info('Test samples number:{}'.format(len(test)))

    return pos, neg, test
def get_svm_detector(svm):
    '''
    导出可以用于cv2.HOGDescriptor()的SVM检测器，实质上是训练好的SVM的支持向量和rho参数组成的列表
    :param svm: 训练好的SVM分类器
    :return: SVM的支持向量和rho参数组成的列表，可用作cv2.HOGDescriptor()的SVM检测器
    '''
    sv = svm.getSupportVectors()
    rho, _, _ = svm.getDecisionFunction(0)
    sv = np.transpose(sv)
    return np.append(sv, [[-rho]], 0)
def test_hog_detect(test, svm_detector, logger):
    '''
    导入测试集，测试结果
    :param test: 测试数据集
    :param svm_detector: 用于HOGDescriptor的SVM检测器
    :param logger: 日志信息打印模块
    :return: 无
    '''

    hog = cv2.HOGDescriptor((windows_W,windows_H), (block_W,block_H), (blockStride_W,blockStride_H), (cell_W,cell_H), bins)
    hog.setSVMDetector(svm_detector)
    # opencv自带的训练好了的分类器
    # hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
    pwd = os.getcwd()
    test_dir = os.path.join(pwd, 'TestData')
    cv2.namedWindow('Detect')
    for f in test:
        file_path = os.path.join(test_dir, f)
        logger.info('Processing {}'.format(file_path))
        img = cv2.imread(file_path)
        rects, _ = hog.detectMultiScale(img, winStride=(blockStride_W,blockStride_H), padding=(8,8), scale=1.05)
        for (x,y,w,h) in rects:
            cv2.rectangle(img, (x,y), (x+w,y+h), (0,0,255), 2)
        cv2.imshow('Detect', img)
        c = cv2.waitKey(0) & 0xff
        if c == 27:
            break
    cv2.destroyAllWindows()
    
    
logger = logger_init()
pos, neg, test = load_data_set(logger=logger)
svm_2 = cv2.ml.SVM_load('svm_hog.xml')
svm_detector_2=get_svm_detector(svm_2)
test_hog_detect(test, svm_detector_2, logger)
# Out:
# 2019-07-29 16:29:09,389 INFO    : Checking data path!
# 2019-07-29 16:29:09,390 INFO    : Current path is:D:\Python\HogFeature
# 2019-07-29 16:29:09,391 INFO    : Positive data path is:D:\Python\HogFeature\Positive
# 2019-07-29 16:29:09,395 INFO    : Positive samples number:924
# 2019-07-29 16:29:09,395 INFO    : Negative data path is:D:\Python\HogFeature\Negative
# 2019-07-29 16:29:09,398 INFO    : Negative samples number:924
# 2019-07-29 16:29:09,399 INFO    : Test data path is:D:\Python\HogFeature\TestData
# 2019-07-29 16:29:09,400 INFO    : Test samples number:179
# 2019-07-29 16:29:44,419 INFO    : Processing D:\Python\HogFeature\TestData\000001.jpg

# %%
1234
# Out:
# 1234
